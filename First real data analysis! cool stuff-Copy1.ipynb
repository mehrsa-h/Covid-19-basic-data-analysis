# %%
import numpy as np
import pandas as pd
import os 
import urllib
# %matplotlib inline

# %%
url="http://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path=os.path.join("data","covid")

# %%
os.makedirs(file_path,exist_ok=True)
csv_path=os.path.join(file_path,"WHO-COVID-19-global-data.csv")
urllib.request.urlretrieve(url,csv_path)
# Out:
# ('data\\covid\\WHO-COVID-19-global-data.csv',
#  <http.client.HTTPMessage at 0x1dc86012370>)

# %%
df=pd.read_csv(csv_path)

# %%
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 124595    2021-06-07           ZW     Zimbabwe       AFRO         21
# 124596    2021-06-08           ZW     Zimbabwe       AFRO         49
# 124597    2021-06-09           ZW     Zimbabwe       AFRO         83
# 124598    2021-06-10           ZW     Zimbabwe       AFRO        111
# 124599    2021-06-11           ZW     Zimbabwe       AFRO         64
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
df_index=df.index
df_index
# Out:
# RangeIndex(start=0, stop=124600, step=1)

# %%
df_cols=df.columns

# %%
df.index.values
# Out:
# array([     0,      1,      2, ..., 124597, 124598, 124599], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2021-06-09', 'ZW', 'Zimbabwe', ..., 39321, 6, 1617],
#        ['2021-06-10', 'ZW', 'Zimbabwe', ..., 39432, 5, 1622],
#        ['2021-06-11', 'ZW', 'Zimbabwe', ..., 39496, 4, 1626]],
#       dtype=object)

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (124600, 8)

# %%
df.head(10)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
# 5    2020-01-08           AF  Afghanistan       EMRO          0
# 6    2020-01-09           AF  Afghanistan       EMRO          0
# 7    2020-01-10           AF  Afghanistan       EMRO          0
# 8    2020-01-11           AF  Afghanistan       EMRO          0
# 9    2020-01-12           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# ...

# %%
df.tail(10)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 124590    2021-06-02           ZW  Zimbabwe       AFRO         37
# 124591    2021-06-03           ZW  Zimbabwe       AFRO         33
# 124592    2021-06-04           ZW  Zimbabwe       AFRO         61
# 124593    2021-06-05           ZW  Zimbabwe       AFRO         52
# 124594    2021-06-06           ZW  Zimbabwe       AFRO         24
# 124595    2021-06-07           ZW  Zimbabwe       AFRO         21
# 124596    2021-06-08           ZW  Zimbabwe       AFRO         49
# 124597    2021-06-09           ZW  Zimbabwe       AFRO         83
# 124598    2021-06-10           ZW  Zimbabwe       AFRO        111
# 124599    2021-06-11           ZW  Zimbabwe       AFRO         64
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 124590             38998           3               1599
# 124591             39031           0               1599
# 124592             39092           5               1604
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124600 entries, 0 to 124599
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      124600 non-null  object
#  1   Country_code       124074 non-null  object
#  2   Country            124600 non-null  object
#  3   WHO_region         124600 non-null  object
#  4   New_cases          124600 non-null  int64
#  5   Cumulative_cases   124600 non-null  int64
#  6   New_deaths         124600 non-null  int64
#  7   Cumulative_deaths  124600 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 7.6+ MB

# %%
df.describe()
# Out:
#            New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  124600.000000      1.246000e+05  124600.000000      124600.000000
# mean     1399.999270      2.267448e+05      30.248692        5537.007897
# std      9631.841168      1.439146e+06     169.887652       29285.135923
# min    -32952.000000      0.000000e+00     -43.000000           0.000000
# 25%         0.000000      1.800000e+01       0.000000           0.000000
# 50%         7.000000      2.301000e+03       0.000000          38.000000
# 75%       289.000000      4.423000e+04       4.000000         734.000000
# max    414188.000000      3.309496e+07    6508.000000      593365.000000

# %%
df['Country']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 124595       Zimbabwe
# 124596       Zimbabwe
# 124597       Zimbabwe
# 124598       Zimbabwe
# 124599       Zimbabwe
# Name: Country, Length: 124600, dtype: object

# %%
df['New_cases']
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 124595     21
# 124596     49
# 124597     83
# 124598    111
# 124599     64
# Name: New_cases, Length: 124600, dtype: int64

# %%
df['New_deaths'].size
# Out:
# 124600

# %%
df['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.columns=[col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.Country
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 124595       Zimbabwe
# 124596       Zimbabwe
# 124597       Zimbabwe
# 124598       Zimbabwe
# 124599       Zimbabwe
# Name: Country, Length: 124600, dtype: object

# %%
df.New_cases
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 124595     21
# 124596     49
# 124597     83
# 124598    111
# 124599     64
# Name: New_cases, Length: 124600, dtype: int64

# %%
df.loc[1:4,'Country']
# Out:
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: Country, dtype: object

# %%
df.loc[3:18,['Country','New_cases','Cumulative_cases']]
# Out:
#         Country  New_cases  Cumulative_cases
# 3   Afghanistan          0                 0
# 4   Afghanistan          0                 0
# 5   Afghanistan          0                 0
# 6   Afghanistan          0                 0
# 7   Afghanistan          0                 0
# 8   Afghanistan          0                 0
# 9   Afghanistan          0                 0
# 10  Afghanistan          0                 0
# 11  Afghanistan          0                 0
# 12  Afghanistan          0                 0
# 13  Afghanistan          0                 0
# 14  Afghanistan          0                 0
# 15  Afghanistan          0                 0
# 16  Afghanistan          0                 0
# 17  Afghanistan          0                 0
# 18  Afghanistan          0                 0

# %%
df.Country=='United States of America'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 124595    False
# 124596    False
# 124597    False
# 124598    False
# 124599    False
# Name: Country, Length: 124600, dtype: bool

# %%
df[df.Country=='United States of America']
# Out:
# array([['2020-01-03', 'US', 'United States of America', ..., 0, 0, 0],
#        ['2020-01-04', 'US', 'United States of America', ..., 0, 0, 0],
#        ['2020-01-05', 'US', 'United States of America', ..., 0, 0, 0],
#        ...,
#        ['2021-06-09', 'US', 'United States of America', ..., 33056361,
#         496, 592610],
#        ['2021-06-10', 'US', 'United States of America', ..., 33072912,
#         322, 592932],
#        ['2021-06-11', 'US', 'United States of America', ..., 33094965,
#         433, 593365]], dtype=object)

# %%
df[df.New_deaths>1000].Country[0:600]
# Out:
# 4480                             Argentina
# 12866     Bolivia (Plurinational State of)
# 14859                               Brazil
# 14861                               Brazil
# 14862                               Brazil
#                         ...
# 119241            United States of America
# 119242            United States of America
# 119243            United States of America
# 119244            United States of America
# 119245            United States of America
# Name: Country, Length: 600, dtype: object

# %%
df.loc[df.New_deaths>1000,['New_deaths','Country']]
# Out:
#         New_deaths                           Country
# 4480          3351                         Argentina
# 12866         1610  Bolivia (Plurinational State of)
# 14859         1179                            Brazil
# 14861         1188                            Brazil
# 14862         1001                            Brazil
# ...            ...                               ...
# 119258        1359          United States of America
# 119263        1091          United States of America
# 119264        1237          United States of America
# 119265        1170          United States of America
# 119326        1120          United States of America
#
# [611 rows x 2 columns]

# %%
df.loc[(df.New_deaths>1000)&(df.Country_code=='US'),['Country','New_cases','New_deaths']]
# Out:
#                          Country  New_cases  New_deaths
# 118908  United States of America      35131        1067
# 118909  United States of America      30593        1157
# 118910  United States of America      25511        1364
# 118911  United States of America      42604        3243
# 118913  United States of America      31714        1958
# ...                          ...        ...         ...
# 119258  United States of America      61405        1359
# 119263  United States of America      65751        1091
# 119264  United States of America      67796        1237
# 119265  United States of America      71388        1170
# 119326  United States of America      24462        1120
#
# [215 rows x 3 columns]

# %%
df.loc[df.Country_code=='US',['New_cases']].max()
# Out:
# New_cases    312247
# dtype: int64

# %%
df.loc[df.Country_code=='US',['New_cases']].min()
# Out:
# New_cases    0
# dtype: int64

# %%
df.loc[df.Country_code=='US',['New_cases']].mean()
# Out:
# New_cases    62918.184411
# dtype: float64

# %%
df[df.New_deaths<0]
# Out:
#        Date_reported Country_code                Country WHO_region  \
# 1265      2020-08-04           DZ                Algeria       AFRO
# 2904      2020-10-05           AO                 Angola       AFRO
# 7599      2020-08-30           BS                Bahamas       AMRO
# 7816      2021-04-04           BS                Bahamas       AMRO
# 17015     2020-07-13           BF           Burkina Faso       AFRO
# 23819     2020-06-09           CG                  Congo       AFRO
# 26515     2020-08-15           CU                   Cuba       AMRO
# 28051     2020-07-05           CZ                Czechia       EURO
# 28052     2020-07-06           CZ                Czechia       EURO
# 34013     2020-12-30           ER                Eritrea       AFRO
# 34098     2021-03-25           ER                Eritrea       AFRO
# 34942     2020-08-30           SZ               Eswatini       AFRO
# 35149     2021-03-25           SZ               Eswatini       AFRO
# ...

# %%
df['pct_cases']=(df['New_cases']/df['Cumulative_cases']*100)
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 124595    2021-06-07           ZW     Zimbabwe       AFRO         21
# 124596    2021-06-08           ZW     Zimbabwe       AFRO         49
# 124597    2021-06-09           ZW     Zimbabwe       AFRO         83
# 124598    2021-06-10           ZW     Zimbabwe       AFRO        111
# 124599    2021-06-11           ZW     Zimbabwe       AFRO         64
#
#         Cumulative_cases  New_deaths  Cumulative_deaths  pst_cases  pct_cases
# ...
